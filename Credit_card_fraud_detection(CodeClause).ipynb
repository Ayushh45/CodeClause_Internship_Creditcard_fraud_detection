# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('/content/creditcard_2.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
df.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1981  1524 -0.340622  1.132232  1.291494  0.062313  0.016387 -0.977070
# 1982  1525 -1.842696  1.740641  0.861526 -0.856315 -0.655376 -0.842786
# 1983  1525 -0.480693  0.646091  1.577264 -0.084411 -0.305958 -0.534739
# 1984  1525 -0.342132  1.091125  1.282729  0.068076 -0.022498 -0.996727
# 1985  1526 -0.854343  1.382948  1.278665  2.914727 -0.183139 -0.349329
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1981  0.723755 -0.074630 -0.396655  ... -0.262948 -0.688785 -0.010937
# 1982  0.198563  0.602764  0.455595  ... -0.213609 -0.400617  0.030013
# 1983  0.860346 -0.028569 -0.800705  ...  0.121681  0.175190  0.035986
# 1984  0.676304 -0.042250 -0.312036  ... -0.269850 -0.734148 -0.007354
# 1985  0.274566  0.435277 -1.576521  ...       NaN       NaN       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# 1981  0.334061 -0.160025  0.071779  0.245128  0.098336    5.35    0.0
# 1982  0.512611 -0.077087  0.286218  0.586012  0.352610    1.00    0.0
# 1983  0.557665 -0.112301  0.337154 -0.015602  0.051504   80.70    0.0
# 1984  0.319161 -0.179146  0.073683  0.241932  0.097139    3.59    0.0
# 1985       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    1986 non-null   int64
#  1   V1      1986 non-null   float64
#  2   V2      1986 non-null   float64
#  3   V3      1986 non-null   float64
#  4   V4      1986 non-null   float64
#  5   V5      1986 non-null   float64
#  6   V6      1986 non-null   float64
#  7   V7      1986 non-null   float64
#  8   V8      1986 non-null   float64
#  9   V9      1986 non-null   float64
#  10  V10     1986 non-null   float64
#  11  V11     1986 non-null   float64
#  12  V12     1986 non-null   float64
#  13  V13     1986 non-null   float64
#  14  V14     1985 non-null   float64
#  15  V15     1985 non-null   float64
#  16  V16     1985 non-null   float64
#  17  V17     1985 non-null   float64
#  18  V18     1985 non-null   float64
#  19  V19     1985 non-null   float64
#  20  V20     1985 non-null   float64
#  21  V21     1985 non-null   float64
#  22  V22     1985 non-null   float64
#  23  V23     1985 non-null   float64
#  24  V24     1985 non-null   float64
#  25  V25     1985 non-null   float64
#  26  V26     1985 non-null   float64
#  27  V27     1985 non-null   float64
#  28  V28     1985 non-null   float64
#  29  Amount  1985 non-null   float64
#  30  Class   1985 non-null   float64
# dtypes: float64(30), int64(1)
# memory usage: 481.1 KB

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# 0.0    1983
# 1.0       2
# Name: Class, dtype: int64

# %%
legit=df[df.Class==0]
fraud=df[df.Class==1]
print(legit)
print(fraud)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 0        0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2        1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3        1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4        2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...    ...       ...       ...       ...       ...       ...       ...
# 1980  1524 -1.278672  1.318588  1.321637 -0.842274 -0.323036 -0.753479
# 1981  1524 -0.340622  1.132232  1.291494  0.062313  0.016387 -0.977070
# 1982  1525 -1.842696  1.740641  0.861526 -0.856315 -0.655376 -0.842786
# 1983  1525 -0.480693  0.646091  1.577264 -0.084411 -0.305958 -0.534739
# 1984  1525 -0.342132  1.091125  1.282729  0.068076 -0.022498 -0.996727
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 0     0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1    -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2     0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3     0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321
# 4     0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
# ...        ...       ...       ...  ...       ...       ...       ...
# 1980  0.595773  0.160145  0.431263  ... -0.228278 -0.365055 -0.023650
# 1981  0.723755 -0.074630 -0.396655  ... -0.262948 -0.688785 -0.010937
# 1982  0.198563  0.602764  0.455595  ... -0.213609 -0.400617  0.030013
# 1983  0.860346 -0.028569 -0.800705  ...  0.121681  0.175190  0.035986
# 1984  0.676304 -0.042250 -0.312036  ... -0.269850 -0.734148 -0.007354
#
#            V24       V25       V26       V27       V28  Amount  Class
# 0     0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62    0.0
# 1    -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69    0.0
# 2    -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3    -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50    0.0
# 4     0.141267 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
# ...        ...       ...       ...       ...       ...     ...    ...
# 1980  0.517183 -0.149327  0.279858  0.608979  0.353802    5.00    0.0
# 1981  0.334061 -0.160025  0.071779  0.245128  0.098336    5.35    0.0
# 1982  0.512611 -0.077087  0.286218  0.586012  0.352610    1.00    0.0
# 1983  0.557665 -0.112301  0.337154 -0.015602  0.051504   80.70    0.0
# 1984  0.319161 -0.179146  0.073683  0.241932  0.097139    3.59    0.0
#
# [1983 rows x 31 columns]
#      Time        V1        V2        V3        V4        V5        V6  \
# 541   406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623   472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 541 -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623  0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
#
#           V24       V25       V26       V27       V28  Amount  Class
# 541  0.320198  0.044519  0.177840  0.261145 -0.143276     0.0    1.0
# 623 -0.293803  0.279798 -0.145362 -0.252773  0.035764   529.0    1.0
#
# [2 rows x 31 columns]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (1983, 31)
# (2, 31)

# %%
legit.Amount.describe()
# Out:
# count    1983.000000
# mean       68.404892
# std       241.572682
# min         0.000000
# 25%         4.950000
# 50%        15.090000
# 75%        63.285000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      2.000000
# mean     264.500000
# std      374.059487
# min        0.000000
# 25%      132.250000
# 50%      264.500000
# 75%      396.750000
# max      529.000000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#              Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    760.974786 -0.281494  0.267200  0.848906  0.146804 -0.077904  0.051713
# 1.0    439.000000 -2.677884 -0.602658 -0.260694  3.143275  0.418809 -1.245684
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.139533 -0.059771  0.014492  ...  0.056618 -0.012217 -0.144666
# 1.0   -1.105907  0.661932 -1.520521  ...  1.114625  0.589464  0.200214
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.043548  0.013865  0.108318  0.049441  0.027220 -0.001966   68.404892
# 1.0    0.455377  0.013198  0.162159  0.016239  0.004186 -0.053756  264.500000
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=146)

# %%
nd = pd.concat([legit_sample,fraud],axis=0)

# %%
nd.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 398    288  1.268069  0.285832 -0.147276  1.047742  0.672115  0.656656
# 1943  1499 -1.344752  1.393214  0.948695 -0.672001 -0.560411 -1.024699
# 1175   917  1.200428 -0.489236 -0.736384 -0.690662 -0.135711 -0.481853
# 690    522 -0.608941  0.961271  0.978330 -0.375420  0.955270 -0.111386
# 858    651 -0.618515  0.713333  2.162786  4.861129  0.802697  0.161066
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 398   0.138315 -0.010785  0.158271  ... -0.177627 -0.189526 -0.251549
# 1943  0.278152  0.478198  0.430051  ... -0.226941 -0.551333 -0.000826
# 1175 -0.074583 -0.137785 -1.448472  ...  0.302955  0.646307 -0.311563
# 690   1.145462 -0.070023 -0.523790  ...  0.034309 -0.010383 -0.425615
# 858  -0.120171  0.114415 -1.746005  ...  0.124022  0.432932  0.008915
#
#            V24       V25       V26       V27       V28  Amount  Class
# 398  -1.266236  0.901899 -0.230845  0.048271  0.004764    6.54    0.0
# 1943  0.369223 -0.140456  0.308572  0.378033  0.236275    1.00    0.0
# 1175 -0.310429  0.736109 -0.017777 -0.015942  0.022911  104.00    0.0
# 690  -1.022448  0.613098 -0.401181  0.051356  0.083632   39.05    0.0
# 858   0.429124 -0.413622  0.330706  0.187837  0.191494    4.20    0.0
#
# [5 rows x 31 columns]

# %%
nd.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1644  1269 -1.325781 -0.945173  2.318450  0.085178  0.096957 -0.675367
# 399    289 -1.782116 -0.326079  2.282092 -0.381814  1.061290  2.666355
# 1306  1025 -2.313163  1.306724 -0.621395 -2.858890  0.302760 -0.592040
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1644  0.187490 -0.013478  0.658664  ...  0.122842  0.102060  0.391234
# 399   0.311426  0.364125  1.080382  ... -0.316547  0.480398  0.193991
# 1306  0.188360 -1.546780  1.808857  ...  1.255734 -0.483164  0.214936
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
#
#            V24       V25       V26       V27       V28  Amount  Class
# 1644  0.381272 -0.347889  0.080227 -0.128394 -0.049484  149.79    0.0
# 399  -1.867208  0.145658  0.491213  0.248133 -0.504045   74.47    0.0
# 1306 -0.864417  0.375697 -0.018250  1.010889  0.586047    8.00    0.0
# 541   0.320198  0.044519  0.177840  0.261145 -0.143276    0.00    1.0
# 623  -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00    1.0
#
# [5 rows x 31 columns]

# %%
nd['Class'].value_counts()
# Out:
# 0.0    146
# 1.0      2
# Name: Class, dtype: int64

# %%
nd.groupby('Class').mean()
# Out:
#              Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    787.075342 -0.205497  0.252813  0.848397  0.166689 -0.017150  0.201784
# 1.0    439.000000 -2.677884 -0.602658 -0.260694  3.143275  0.418809 -1.245684
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.032262  0.026704 -0.045501  ...  0.070373 -0.045284 -0.076431
# 1.0   -1.105907  0.661932 -1.520521  ...  1.114625  0.589464  0.200214
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.040840  0.026682  0.129779  0.025933  0.021913  0.003649   61.664247
# 1.0    0.455377  0.013198  0.162159  0.016239  0.004186 -0.053756  264.500000
#
# [2 rows x 30 columns]

# %%
X=nd.drop(columns='Class',axis=1)
Y=nd['Class']

# %%
print(X)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 398    288  1.268069  0.285832 -0.147276  1.047742  0.672115  0.656656
# 1943  1499 -1.344752  1.393214  0.948695 -0.672001 -0.560411 -1.024699
# 1175   917  1.200428 -0.489236 -0.736384 -0.690662 -0.135711 -0.481853
# 690    522 -0.608941  0.961271  0.978330 -0.375420  0.955270 -0.111386
# 858    651 -0.618515  0.713333  2.162786  4.861129  0.802697  0.161066
# ...    ...       ...       ...       ...       ...       ...       ...
# 1644  1269 -1.325781 -0.945173  2.318450  0.085178  0.096957 -0.675367
# 399    289 -1.782116 -0.326079  2.282092 -0.381814  1.061290  2.666355
# 1306  1025 -2.313163  1.306724 -0.621395 -2.858890  0.302760 -0.592040
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#             V7        V8        V9  ...       V20       V21       V22  \
# 398   0.138315 -0.010785  0.158271  ... -0.051828 -0.177627 -0.189526
# 1943  0.278152  0.478198  0.430051  ...  0.069672 -0.226941 -0.551333
# 1175 -0.074583 -0.137785 -1.448472  ...  0.294498  0.302955  0.646307
# 690   1.145462 -0.070023 -0.523790  ... -0.045865  0.034309 -0.010383
# 858  -0.120171  0.114415 -1.746005  ...  0.421457  0.124022  0.432932
# ...        ...       ...       ...  ...       ...       ...       ...
# 1644  0.187490 -0.013478  0.658664  ...  0.458782  0.122842  0.102060
# 399   0.311426  0.364125  1.080382  ...  0.179087 -0.316547  0.480398
# 1306  0.188360 -1.546780  1.808857  ...  0.011980  1.255734 -0.483164
# 541  -2.537387  1.391657 -2.770089  ...  0.126911  0.517232 -0.035049
# 623   0.325574 -0.067794 -0.270953  ...  2.102339  0.661696  0.435477
#
#            V23       V24       V25       V26       V27       V28  Amount
# 398  -0.251549 -1.266236  0.901899 -0.230845  0.048271  0.004764    6.54
# 1943 -0.000826  0.369223 -0.140456  0.308572  0.378033  0.236275    1.00
# 1175 -0.311563 -0.310429  0.736109 -0.017777 -0.015942  0.022911  104.00
# 690  -0.425615 -1.022448  0.613098 -0.401181  0.051356  0.083632   39.05
# 858   0.008915  0.429124 -0.413622  0.330706  0.187837  0.191494    4.20
# ...        ...       ...       ...       ...       ...       ...     ...
# 1644  0.391234  0.381272 -0.347889  0.080227 -0.128394 -0.049484  149.79
# 399   0.193991 -1.867208  0.145658  0.491213  0.248133 -0.504045   74.47
# 1306  0.214936 -0.864417  0.375697 -0.018250  1.010889  0.586047    8.00
# 541  -0.465211  0.320198  0.044519  0.177840  0.261145 -0.143276    0.00
# 623   1.375966 -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00
#
# [148 rows x 30 columns]

# %%
print(Y)
# Out:
# 398     0.0
# 1943    0.0
# 1175    0.0
# 690     0.0
# 858     0.0
#        ...
# 1644    0.0
# 399     0.0
# 1306    0.0
# 541     1.0
# 623     1.0
# Name: Class, Length: 148, dtype: float64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (148, 30) (118, 30) (30, 30)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on training Data',training_data_accuracy)
# Out:
# Accuracy on training Data 1.0

# %%
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy on test Data',training_data_accuracy)
# Out:
# Accuracy on test Data 1.0
